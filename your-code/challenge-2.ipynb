# %% [markdown]
# # Challenge 2: Sentiment Analysis
#
# In this challenge we will learn sentiment analysis and practice performing sentiment analysis on Twitter tweets.
#
# ## Introduction
#
# Sentiment analysis is to *systematically identify, extract, quantify, and study affective states and subjective information* based on texts ([reference](https://en.wikipedia.org/wiki/Sentiment_analysis)). In simple words, it's to understand whether a person is happy or unhappy in producing the piece of text. Why we (or rather, companies) care about sentiment in texts? It's because by understanding the sentiments in texts, we will be able to know if our customers are happy or unhappy about our products and services. If they are unhappy, the subsequent action is to figure out what have caused the unhappiness and make improvements.
#
# Basic sentiment analysis only understands the *positive* or *negative* (sometimes *neutral* too) polarities of the sentiment. More advanced sentiment analysis will also consider dimensions such as agreement, subjectivity, confidence, irony, and so on. In this challenge we will conduct the basic positive vs negative sentiment analysis based on real Twitter tweets.
#
# NLTK comes with a [sentiment analysis package](https://www.nltk.org/api/nltk.sentiment.html). This package is great for dummies to perform sentiment analysis because it requires only the textual data to make predictions. For example:
#
# ```python
# >>> from nltk.sentiment.vader import SentimentIntensityAnalyzer
# >>> txt = "Ironhack is a Global Tech School ranked num 2 worldwide. Our mission is to help people transform their careers and join a thriving community of tech professionals that love what they do."
# >>> analyzer = SentimentIntensityAnalyzer()
# >>> analyzer.polarity_scores(txt)
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.8442}
# ```
#
# In this challenge, however, you will not use NLTK's sentiment analysis package because in your Machine Learning training in the past 2 weeks you have learned how to make predictions more accurate than that. The [tweets data](https://www.kaggle.com/kazanova/sentiment140) we will be using today are already coded for the positive/negative sentiment. You will be able to use the Naïve Bayes classifier you learned in the lesson to predict the sentiment of tweets based on the labels.

# %%
# %run challenge-1.ipynb

# %% [markdown]
# ## Conducting Sentiment Analysis
#
# ### Loading and Exploring Data
#
# The dataset we'll be using today is located on Kaggle (https://www.kaggle.com/kazanova/sentiment140). Once you have downloaded and imported the dataset, it you will need to define the columns names: df.columns = ['target','id','date','flag','user','text']
#
# *Notes:*
#
# * The dataset is huuuuge (1.6m tweets). When you develop your data analysis codes, you can sample a subset of the data (e.g. 20k records) so that you will save a lot of time when you test your codes.

# %%
import pandas as pd


data = pd.read_csv('/Users/lucaalfano/IH-labs/trainingprocessed.csv', encoding = "ISO-8859-1")
# data = data[:100]
# data
data.columns = ['target','id','date','flag','user','text']
data
# Out:
#          target          id                          date      flag  \
# 0             0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 1             0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 2             0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 3             0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4             0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1599994       4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599995       4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996       4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997       4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998       4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# 0          scotthamilton  is upset that he can't update his Facebook by ...
# 1               mattycus  @Kenichan I dived many times for the ball. Man...
# 2                ElleCTF    my whole body feels itchy and like its on fire
# 3                 Karoli  @nationwideclass no, it's not behaving at all....
# 4               joy_wolf                      @Kwesidei not the whole crew
# ...                  ...                                                ...
# 1599994  AmandaMarie1028  Just woke up. Having no school is the best fee...
# 1599995      TheWDBoards  TheWDB.com - Very cool to hear old Walt interv...
# 1599996           bpbabe  Are you ready for your MoJo Makeover? Ask me f...
# 1599997     tinydiamondz  Happy 38th Birthday to my boo of alll time!!! ...
# 1599998   RyanTrevMorris  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1599999 rows x 6 columns]

# %%
df = data.sample(1000)
df
# Out:
#          target          id                          date      flag  \
# 259888        0  1985540609  Sun May 31 17:18:01 PDT 2009  NO_QUERY
# 650568        0  2237605567  Fri Jun 19 06:04:34 PDT 2009  NO_QUERY
# 1572539       4  2188943798  Mon Jun 15 22:53:56 PDT 2009  NO_QUERY
# 222721        0  1977066137  Sat May 30 20:00:50 PDT 2009  NO_QUERY
# 1521373       4  2176313089  Mon Jun 15 03:31:39 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 841023        4  1559940151  Sun Apr 19 12:26:16 PDT 2009  NO_QUERY
# 510391        0  2189644420  Tue Jun 16 00:32:11 PDT 2009  NO_QUERY
# 1139169       4  1976905973  Sat May 30 19:30:45 PDT 2009  NO_QUERY
# 514018        0  2190522676  Tue Jun 16 02:58:32 PDT 2009  NO_QUERY
# 102410        0  1794990322  Thu May 14 06:57:10 PDT 2009  NO_QUERY
#
#                     user                                               text
# 259888           dcutler                 Waiting for the train in the cold
# 650568   apache_e_bozorg  i'm so tired, i had an exam today and now i'm ...
# 1572539      arunmvishnu  Running my first Adobe AIR application.. Ohh i...
# 222721        Luvlynikki  http://twitpic.com/6b5qy - i dropped my ice cr...
# 1521373           sermoa  @nyecamden Wahey! What did you do in command l...
# ...                  ...                                                ...
# 841023       linnetwoods     @knikkolette Great thanks! How are you doing?
# 510391        sjspratlin  Ready for tomorrow night! And to get this test...
# 1139169     Rebekah_Anne        Had a dinner date with my husband tonight.
# 514018        tilda_dahl  ergh tummy is still sore. I'm so weak when it ...
# 102410       Goldielox73  @StacyOnBob @PhilOnBob  Your online stream is ...
#
# [1000 rows x 6 columns]

# %% [markdown]
# ### Prepare Textual Data for Sentiment Analysis
#
# Now, apply the functions you have written in Challenge 1 to your whole data set. These functions include:
#
# * `clean_up()`
#
# * `tokenize()`
#
# * `stem_and_lemmatize()`
#
# * `remove_stopwords()`
#
# Create a new column called `text_processed` in the dataframe to contain the processed data. At the end, your `text_processed` column should contain lists of word tokens that are cleaned up. Your data should look like below:
#
# ![Processed Data](data-cleaning-results.png)

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re
def clean_up(s):    
    lower = s.lower()
    no_url = re.sub('http\S+', '',lower)
    str_list = re.findall('[a-z]+',no_url)
    return ' '.join(str_list)

def tokenize(s):
    tokens = word_tokenize(s)
    return tokens

def stem_and_lemmatize(s):
    ps = PorterStemmer()
    stemmed = [ps.stem(w) for w in s]
    
    lemmatizer = WordNetLemmatizer() 
    lemmatized = [lemmatizer.lemmatize(word) for word in s]
    
    return lemmatized


def remove_stopwords(l): 
    return [word for word in l if not word in stopwords.words('english')]

# [word for word in l if not word in stopwords.words('english')]

# %%
# %%time

df['text_processed'] = df['text'].apply(clean_up)
df['text_processed'] = df['text_processed'].apply(tokenize)
df['text_processed'] = df['text_processed'].apply(stem_and_lemmatize)
df['text_processed'] = df['text_processed'].apply(remove_stopwords) 
df
# Out:
# CPU times: user 1.67 s, sys: 382 ms, total: 2.05 s
# Wall time: 2.07 s
#          target          id                          date      flag  \
# 259888        0  1985540609  Sun May 31 17:18:01 PDT 2009  NO_QUERY
# 650568        0  2237605567  Fri Jun 19 06:04:34 PDT 2009  NO_QUERY
# 1572539       4  2188943798  Mon Jun 15 22:53:56 PDT 2009  NO_QUERY
# 222721        0  1977066137  Sat May 30 20:00:50 PDT 2009  NO_QUERY
# 1521373       4  2176313089  Mon Jun 15 03:31:39 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 841023        4  1559940151  Sun Apr 19 12:26:16 PDT 2009  NO_QUERY
# 510391        0  2189644420  Tue Jun 16 00:32:11 PDT 2009  NO_QUERY
# 1139169       4  1976905973  Sat May 30 19:30:45 PDT 2009  NO_QUERY
# 514018        0  2190522676  Tue Jun 16 02:58:32 PDT 2009  NO_QUERY
# 102410        0  1794990322  Thu May 14 06:57:10 PDT 2009  NO_QUERY
#
#                     user                                               text  \
# 259888           dcutler                 Waiting for the train in the cold
# 650568   apache_e_bozorg  i'm so tired, i had an exam today and now i'm ...
# 1572539      arunmvishnu  Running my first Adobe AIR application.. Ohh i...
# 222721        Luvlynikki  http://twitpic.com/6b5qy - i dropped my ice cr...
# 1521373           sermoa  @nyecamden Wahey! What did you do in command l...
# ...                  ...                                                ...
# 841023       linnetwoods     @knikkolette Great thanks! How are you doing?
# 510391        sjspratlin  Ready for tomorrow night! And to get this test...
# 1139169     Rebekah_Anne        Had a dinner date with my husband tonight.
# 514018        tilda_dahl  ergh tummy is still sore. I'm so weak when it ...
# 102410       Goldielox73  @StacyOnBob @PhilOnBob  Your online stream is ...
#
#                                             text_processed
# 259888                              [waiting, train, cold]
# 650568   [tired, exam, today, going, wedding, party, si...
# 1572539  [running, first, adobe, air, application, ohh,...
# 222721                               [dropped, ice, cream]
# 1521373         [nyecamden, wahey, command, line, excited]
# ...                                                    ...
# 841023                        [knikkolette, great, thanks]
# 510391   [ready, tomorrow, night, get, test, lovveee, l...
# 1139169                   [dinner, date, husband, tonight]
# 514018        [ergh, tummy, still, sore, weak, come, pain]
# 102410   [stacyonbob, philonbob, online, stream, workin...
#
# [1000 rows x 7 columns]

# %%
# t = []
# for i in df['text']:
#     t.append(remove_stopwords(stem_and_lemmatize(tokenize(clean_up(i)))))

# %% [markdown]
# ### Creating Bag of Words
#
# The purpose of this step is to create a [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) from the processed data. The bag of words contains all the unique words in your whole text body (a.k.a. *corpus*) with the number of occurrence of each word. It will allow you to understand which words are the most important features across the whole corpus.
#
# Also, you can imagine you will have a massive set of words. The less important words (i.e. those of very low number of occurrence) do not contribute much to the sentiment. Therefore, you only need to use the most important words to build your feature set in the next step. In our case, we will use the top 5,000 words with the highest frequency to build the features.
#
# In the cell below, combine all the words in `text_processed` and calculate the frequency distribution of all words. A convenient library to calculate the term frequency distribution is NLTK's `FreqDist` class ([documentation](https://www.nltk.org/api/nltk.html#module-nltk.probability)). Then select the top 5,000 words from the frequency distribution.

# %%
# your code here
pos = []

for x in df['text_processed']:
    for word in x:
        pos.append(word)

# %%
df['text_processed']
# Out:
# 259888                                [waiting, train, cold]
# 650568     [tired, exam, today, going, wedding, party, si...
# 1572539    [running, first, adobe, air, application, ohh,...
# 222721                                 [dropped, ice, cream]
# 1521373           [nyecamden, wahey, command, line, excited]
#                                  ...
# 841023                          [knikkolette, great, thanks]
# 510391     [ready, tomorrow, night, get, test, lovveee, l...
# 1139169                     [dinner, date, husband, tonight]
# 514018          [ergh, tummy, still, sore, weak, come, pain]
# 102410     [stacyonbob, philonbob, online, stream, workin...
# Name: text_processed, Length: 1000, dtype: object

# %%
pos
# Out:
# ['waiting',
#  'train',
#  'cold',
#  'tired',
#  'exam',
#  'today',
#  'going',
#  'wedding',
#  'party',
#  'situation',
#  'ad',
#  'mad',
#  'khamenei',
#  'speech',
#  'running',
#  'first',
#  'adobe',
#  'air',
#  'application',
#  'ohh',
#  'itz',
#  'hello',
#  'world',
#  'application',
#  'dropped',
#  'ice',
#  'cream',
#  'nyecamden',
#  'wahey',
#  'command',
#  'line',
#  'excited',
#  'benlovesorhates',
#  'hi',
#  'ben',
#  'banksyart',
#  'banksyart',
#  'ha',
#  'posting',
#  'since',
#  'probs',
#  'banksyart',
#  'account',
#  'peace',
#  'rana',
#  'xx',
#  'im',
#  'siccckkk',
#  'sooo',
#  'gay',
#  'thats',
#  'sounded',
#  'like',
#  'man',
#  'wa',
#  'tired',
#  'saturday',
#  'ha',
#  'vatd',
#  'noooo',
#  'still',
#  'would',
#  'like',
#  'hug',
#  'morcheeba',
#  'site',
#  'doe',
#  'work',
#  'apache',
#  'default',
#  'site',
#  'well',
#  'obviously',
#  'wide',
#  'awake',
#  'day',
#  'sooooo',
#  'time',
#  'make',
#  'coffee',
#  'weeeeeeeeeee',
#  'rainy',
#  'sunday',
#  'parking',
#  'lot',
#  'cricket',
#  'today',
#  'sea',
#  'light',
#  'person',
#  'end',
#  'vide',
#  'kid',
#  'well',
#  'come',
#  'bmore',
#  'u',
#  'puppy',
#  'give',
#  'lot',
#  'love',
#  'even',
#  'stupid',
#  'mmyb',
#  'stand',
#  'corrected',
#  'raining',
#  'cant',
#  'sleep',
#  'sad',
#  'face',
#  'need',
#  'leave',
#  'real',
#  'soon',
#  'scared',
#  'gunna',
#  'rain',
#  'listening',
#  'stm',
#  'go',
#  'ahaulil',
#  'bird',
#  'living',
#  'find',
#  'way',
#  'kill',
#  'damn',
#  'thing',
#  'beside',
#  'exterminator',
#  'vega',
#  'suck',
#  'eric',
#  'lemus',
#  'ya',
#  'check',
#  'dlist',
#  'party',
#  'pic',
#  'taken',
#  'girl',
#  'dawniellerene',
#  'happy',
#  'mother',
#  'day',
#  'mum',
#  'eat',
#  'breakfast',
#  'made',
#  'anna',
#  'presso',
#  'lol',
#  'reading',
#  'blog',
#  'think',
#  'team',
#  'u',
#  'dumb',
#  'brit',
#  'notice',
#  'peculiar',
#  'nuisance',
#  'setanta',
#  'le',
#  'sleeping',
#  'floor',
#  'millys',
#  'desk',
#  'mtv',
#  'tired',
#  'family',
#  'fun',
#  'night',
#  'wa',
#  'fun',
#  'exhausted',
#  'working',
#  'another',
#  'carnival',
#  'tomorrow',
#  'blah',
#  'samithegreat',
#  'wa',
#  'wet',
#  'attic',
#  'jasperrrr',
#  'got',
#  'bigg',
#  'fight',
#  'prom',
#  'date',
#  'guess',
#  'date',
#  'prom',
#  'suck',
#  'mee',
#  'beautifulloser',
#  'see',
#  'use',
#  'one',
#  'funny',
#  'one',
#  'normal',
#  'seriously',
#  'im',
#  'using',
#  'ginger',
#  'one',
#  'haha',
#  'looked',
#  'happy',
#  'lot',
#  'swhelband',
#  'ok',
#  'thanks',
#  'head',
#  'looking',
#  'forward',
#  'erwinspinueva',
#  'much',
#  'time',
#  'til',
#  'bone',
#  'cheese',
#  'egg',
#  'n',
#  'welchs',
#  'grape',
#  'loll',
#  'omg',
#  'anyone',
#  'see',
#  'finale',
#  'hill',
#  'last',
#  'night',
#  'missed',
#  'watching',
#  'entourage',
#  'tommcfly',
#  'doesnt',
#  'make',
#  'sense',
#  'josamuffin',
#  'migotogirl',
#  'get',
#  'iphone',
#  'great',
#  'band',
#  'broke',
#  'week',
#  'depressing',
#  'mileycyrus',
#  'yay',
#  'congrats',
#  'one',
#  'voted',
#  'wa',
#  'enjoying',
#  'heat',
#  'yesterday',
#  'getting',
#  'bit',
#  'much',
#  'pajjie',
#  'yea',
#  'good',
#  'thing',
#  'monday',
#  'end',
#  'quite',
#  'fast',
#  'jmatthewflyzik',
#  'yay',
#  'good',
#  'morning',
#  'feel',
#  'like',
#  'person',
#  'without',
#  'iphone',
#  'want',
#  'one',
#  'baaaaaad',
#  'trackle',
#  'squarespace',
#  'dannymcfly',
#  'danny',
#  'propa',
#  'love',
#  'teeth',
#  'way',
#  'white',
#  'manchseter',
#  'gig',
#  'alreet',
#  'hows',
#  'ur',
#  'show',
#  'going',
#  'x',
#  'ly',
#  'xx',
#  'rolled',
#  'hunter',
#  'blush',
#  'play',
#  'wife',
#  'new',
#  'paladin',
#  'recruit',
#  'friend',
#  'pretty',
#  'fun',
#  'hope',
#  'terrorize',
#  'bgs',
#  'soon',
#  'mdobson',
#  'like',
#  'original',
#  'title',
#  'better',
#  'lot',
#  'thing',
#  'author',
#  'control',
#  'including',
#  'cover',
#  'sorry',
#  'people',
#  'come',
#  'twitter',
#  'pc',
#  'becose',
#  'im',
#  'holland',
#  'twitter',
#  'dont',
#  'let',
#  'send',
#  'msn',
#  'mobile',
#  'said',
#  'amp',
#  'say',
#  'love',
#  'gray',
#  'hair',
#  'wish',
#  'silver',
#  'streak',
#  'like',
#  'stacy',
#  'london',
#  'lol',
#  'use',
#  'word',
#  'pant',
#  'eddieizzard',
#  'seems',
#  'caused',
#  'confusion',
#  'explain',
#  'everyone',
#  'loveodt',
#  'kim',
#  'u',
#  'r',
#  'freakin',
#  'funny',
#  'love',
#  'robsmada',
#  'thanks',
#  'valilor',
#  'yeah',
#  'seems',
#  'much',
#  'better',
#  'twitterfon',
#  'child',
#  'work',
#  'driving',
#  'freaking',
#  'crazy',
#  'ugh',
#  'hope',
#  'well',
#  'jazz',
#  'appreciation',
#  'test',
#  'tonight',
#  'hummingbird',
#  'fave',
#  'faves',
#  'dunno',
#  'beautiful',
#  'day',
#  'today',
#  'think',
#  'go',
#  'take',
#  'walk',
#  'funny',
#  'finally',
#  'get',
#  'used',
#  'getting',
#  'early',
#  'last',
#  'day',
#  'gme',
#  'week',
#  'oh',
#  'well',
#  'wishing',
#  'work',
#  'tonight',
#  'im',
#  'home',
#  'sober',
#  'loser',
#  'co',
#  'worker',
#  'jake',
#  'drunk',
#  'fuck',
#  'open',
#  'tomorrow',
#  'excited',
#  'gon',
#  'na',
#  'dr',
#  'fitness',
#  'amp',
#  'fatguy',
#  'radio',
#  'show',
#  'october',
#  'dang',
#  'book',
#  'peep',
#  'gpok',
#  'download',
#  'user',
#  'account',
#  'kirasworld',
#  'bf',
#  'know',
#  'nothing',
#  'art',
#  'draw',
#  'like',
#  'lol',
#  'thanks',
#  'anyway',
#  'goodnight',
#  'thomasfiss',
#  'hey',
#  'thomas',
#  'really',
#  'sad',
#  'band',
#  'actually',
#  'made',
#  'shed',
#  'tear',
#  'still',
#  'love',
#  'u',
#  'much',
#  'eliiiiza',
#  'lol',
#  'hope',
#  'turn',
#  'nice',
#  'rice',
#  'reefergladness',
#  'technically',
#  'wa',
#  'nomnomnom',
#  'keij',
#  'duboce',
#  'triangle',
#  'got',
#  'back',
#  'london',
#  'duckydoestv',
#  'joy',
#  'moving',
#  'hope',
#  'ikea',
#  'bookcase',
#  'go',
#  'back',
#  'together',
#  'ok',
#  'urhot',
#  'trying',
#  'girl',
#  'believe',
#  'powerful',
#  'negativity',
#  'stronger',
#  'know',
#  'totally',
#  'going',
#  'tomorrow',
#  'peachypictures',
#  'annoying',
#  'hope',
#  'result',
#  'good',
#  'jer',
#  'quite',
#  'alright',
#  'lake',
#  'murray',
#  'duck',
#  'crazy',
#  'minnie',
#  'best',
#  'friend',
#  'ever',
#  'home',
#  'evening',
#  'looking',
#  'forward',
#  'relaxing',
#  'cheking',
#  'youtube',
#  'fafinettex',
#  'amp',
#  'hardy',
#  'show',
#  'love',
#  'ya',
#  'desinfecting',
#  'hand',
#  'one',
#  'mlre',
#  'time',
#  'finishing',
#  'quite',
#  'chilly',
#  'nightshift',
#  'good',
#  'nite',
#  'good',
#  'morning',
#  'whatever',
#  'im',
#  'zzzzzzz',
#  'physical',
#  'coo',
#  'know',
#  'lettin',
#  'steam',
#  'newly',
#  'seeded',
#  'lawn',
#  'loving',
#  'rain',
#  'see',
#  'steve',
#  'coogan',
#  'raise',
#  'dylan',
#  'moran',
#  'sniff',
#  'never',
#  'got',
#  'chance',
#  'say',
#  'goodbye',
#  'adrian',
#  'long',
#  'rip',
#  'good',
#  'friend',
#  'kraziyanto',
#  'funny',
#  'advice',
#  'true',
#  'timhaines',
#  'saw',
#  'dave',
#  'message',
#  'sorry',
#  'hear',
#  'jenniferkee',
#  'worse',
#  'yet',
#  'receive',
#  'good',
#  'news',
#  'yeah',
#  'great',
#  'news',
#  'best',
#  'know',
#  'rather',
#  'dark',
#  'rhcp',
#  'universe',
#  'big',
#  'green',
#  'day',
#  'fan',
#  'prefer',
#  'rhcp',
#  'though',
#  'still',
#  'waiting',
#  'litmus',
#  'let',
#  'go',
#  'scattering',
#  'picture',
#  'new',
#  'design',
#  'website',
#  'want',
#  'check',
#  'go',
#  'www',
#  'studiokaydesigns',
#  'com',
#  'encore',
#  'htm',
#  'hottea',
#  'good',
#  'night',
#  'fellow',
#  'otaku',
#  'sweet',
#  'dream',
#  'good',
#  'morning',
#  'twitter',
#  'school',
#  'trying',
#  'sport',
#  'day',
#  'yet',
#  'agin',
#  'today',
#  'omg',
#  'computer',
#  'angry',
#  'selenagomez',
#  'um',
#  'id',
#  'say',
#  'im',
#  'cool',
#  'hah',
#  'promise',
#  'come',
#  'fort',
#  'wayne',
#  'cant',
#  'study',
#  'omg',
#  'school',
#  'already',
#  'everyone',
#  'else',
#  'gruesome',
#  'internet',
#  'connection',
#  'problem',
#  'today',
#  'burned',
#  'three',
#  'hour',
#  'trying',
#  'fix',
#  'booo',
#  'tryna',
#  'switch',
#  'movie',
#  'n',
#  'momz',
#  'hang',
#  'blessed',
#  'mom',
#  'today',
#  'home',
#  'work',
#  'saw',
#  'brother',
#  'moment',
#  'today',
#  'going',
#  'bed',
#  'try',
#  'figuring',
#  'twitter',
#  'business',
#  'later',
#  'christinalemmey',
#  'yay',
#  'good',
#  'morning',
#  'take',
#  'dh',
#  'hospital',
#  'today',
#  'due',
#  'abdomenal',
#  'pain',
#  'hour',
#  'clean',
#  'house',
#  'mom',
#  'ok',
#  'beloved',
#  'twitter',
#  'friend',
#  'done',
#  'night',
#  'amp',
#  'excuse',
#  'followfriday',
#  'coz',
#  'busy',
#  'day',
#  'ahead',
#  'love',
#  'u',
#  'gethighonair',
#  'need',
#  'hang',
#  'sometime',
#  'miss',
#  'aidan',
#  'damnn',
#  'sooo',
#  'many',
#  'tutions',
#  'fucking',
#  'frustrating',
#  'got',
#  'la',
#  'campus',
#  'love',
#  'energy',
#  'place',
#  'celsbels',
#  'aha',
#  'ride',
#  'office',
#  'bike',
#  'seriously',
#  'loathe',
#  'royal',
#  'mail',
#  'inflicting',
#  'alwaysatlukoil',
#  'phone',
#  'mean',
#  'like',
#  'friend',
#  'phone',
#  'text',
#  'ipod',
#  'touch',
#  'though',
#  'wifi',
#  'yay',
#  'twitter',
#  'fun',
#  'mrsddoubleu',
#  'last',
#  'least',
#  'call',
#  'bully',
#  'dmwilsonh',
#  'love',
#  'blazer',
#  'putting',
#  'dibs',
#  'one',
#  'yr',
#  'really',
#  'want',
#  'one',
#  'dollar',
#  'portebello',
#  'mushroom',
#  'burger',
#  'arnt',
#  'carl',
#  'jr',
#  'around',
#  'atlanta',
#  'suck',
#  'judez',
#  'xo',
#  'pfft',
#  'great',
#  'venue',
#  'close',
#  'awekay',
#  'r',
#  'u',
#  'going',
#  'see',
#  'kelsey',
#  'haha',
#  'yeah',
#  'thing',
#  'happened',
#  'tried',
#  'upload',
#  'new',
#  'picture',
#  'lol',
#  'back',
#  'later',
#  'stuck',
#  'boy',
#  'fill',
#  'joy',
#  'dear',
#  'louise',
#  'rennison',
#  'pls',
#  'writing',
#  'georgia',
#  'begs',
#  'bereft',
#  'knowing',
#  'wa',
#  'last',
#  'one',
#  'billinman',
#  'four',
#  'letter',
#  'domain',
#  'got',
#  'shore',
#  'com',
#  'free',
#  'feeling',
#  'sick',
#  'hate',
#  'feeling',
#  'weather',
#  'helping',
#  'fact',
#  'got',
#  'sleep',
#  'last',
#  'nite',
#  'hella',
#  'tired',
#  'work',
#  'happy',
#  'birthday',
#  'godmother',
#  'best',
#  'yea',
#  'watching',
#  'tv',
#  'pain',
#  'e',
#  'bueno',
#  'papagai',
#  'sorry',
#  'u',
#  'promotion',
#  'addys',
#  'mom',
#  'hello',
#  'new',
#  'iphone',
#  'im',
#  'jealous',
#  'maybe',
#  'one',
#  'verizon',
#  'much',
#  'drink',
#  'work',
#  'make',
#  'cry',
#  'said',
#  'goodbye',
#  'one',
#  'favorite',
#  'people',
#  'work',
#  'today',
#  'moving',
#  'greener',
#  'pasture',
#  'sure',
#  'going',
#  'miss',
#  'sheila',
#  'back',
#  'work',
#  'least',
#  'give',
#  'money',
#  'stuff',
#  'whats',
#  'deal',
#  'tonight',
#  'pwease',
#  'get',
#  'fucked',
#  'angel',
#  'amp',
#  'demon',
#  'wa',
#  'pretty',
#  'thrilling',
#  'liked',
#  'da',
#  'vinci',
#  'code',
#  'definitely',
#  'going',
#  'read',
#  'book',
#  'even',
#  'better',
#  'mcgrewsecurity',
#  'sure',
#  'heard',
#  'one',
#  'sound',
#  'right',
#  'hollywilli',
#  'jcab',
#  'yer',
#  'preachin',
#  'choir',
#  'baby',
#  'know',
#  'go',
#  'ti',
#  'shit',
#  'sometimes',
#  'lol',
#  'sangfroid',
#  'idea',
#  'ngfr',
#  'yup',
#  'get',
#  'catch',
#  'bit',
#  'late',
#  'tweet',
#  'wendytanwhite',
#  'ok',
#  'colour',
#  'stupid',
#  'open',
#  'soho',
#  'oh',
#  'good',
#  'see',
#  'weekend',
#  'emmadawson',
#  'sound',
#  'nice',
#  'hair',
#  'dog',
#  'boho',
#  'canterbury',
#  'nice',
#  'nicolesayss',
#  'legittt',
#  'one',
#  'armed',
#  'high',
#  'drummer',
#  'woooh',
#  'quot',
#  'watching',
#  'click',
#  'sad',
#  'sad',
#  'movie',
#  'joeymcintyre',
#  'ready',
#  'see',
#  'atl',
#  'thursday',
#  'wait',
#  'ahhh',
#  'manage',
#  'pack',
#  'nike',
#  'box',
#  ...]

# %%
import nltk
flist = nltk.FreqDist(pos)

wlist = list(flist.keys())[:5000]
wlist
# Out:
# ['waiting',
#  'train',
#  'cold',
#  'tired',
#  'exam',
#  'today',
#  'going',
#  'wedding',
#  'party',
#  'situation',
#  'ad',
#  'mad',
#  'khamenei',
#  'speech',
#  'running',
#  'first',
#  'adobe',
#  'air',
#  'application',
#  'ohh',
#  'itz',
#  'hello',
#  'world',
#  'dropped',
#  'ice',
#  'cream',
#  'nyecamden',
#  'wahey',
#  'command',
#  'line',
#  'excited',
#  'benlovesorhates',
#  'hi',
#  'ben',
#  'banksyart',
#  'ha',
#  'posting',
#  'since',
#  'probs',
#  'account',
#  'peace',
#  'rana',
#  'xx',
#  'im',
#  'siccckkk',
#  'sooo',
#  'gay',
#  'thats',
#  'sounded',
#  'like',
#  'man',
#  'wa',
#  'saturday',
#  'vatd',
#  'noooo',
#  'still',
#  'would',
#  'hug',
#  'morcheeba',
#  'site',
#  'doe',
#  'work',
#  'apache',
#  'default',
#  'well',
#  'obviously',
#  'wide',
#  'awake',
#  'day',
#  'sooooo',
#  'time',
#  'make',
#  'coffee',
#  'weeeeeeeeeee',
#  'rainy',
#  'sunday',
#  'parking',
#  'lot',
#  'cricket',
#  'sea',
#  'light',
#  'person',
#  'end',
#  'vide',
#  'kid',
#  'come',
#  'bmore',
#  'u',
#  'puppy',
#  'give',
#  'love',
#  'even',
#  'stupid',
#  'mmyb',
#  'stand',
#  'corrected',
#  'raining',
#  'cant',
#  'sleep',
#  'sad',
#  'face',
#  'need',
#  'leave',
#  'real',
#  'soon',
#  'scared',
#  'gunna',
#  'rain',
#  'listening',
#  'stm',
#  'go',
#  'ahaulil',
#  'bird',
#  'living',
#  'find',
#  'way',
#  'kill',
#  'damn',
#  'thing',
#  'beside',
#  'exterminator',
#  'vega',
#  'suck',
#  'eric',
#  'lemus',
#  'ya',
#  'check',
#  'dlist',
#  'pic',
#  'taken',
#  'girl',
#  'dawniellerene',
#  'happy',
#  'mother',
#  'mum',
#  'eat',
#  'breakfast',
#  'made',
#  'anna',
#  'presso',
#  'lol',
#  'reading',
#  'blog',
#  'think',
#  'team',
#  'dumb',
#  'brit',
#  'notice',
#  'peculiar',
#  'nuisance',
#  'setanta',
#  'le',
#  'sleeping',
#  'floor',
#  'millys',
#  'desk',
#  'mtv',
#  'family',
#  'fun',
#  'night',
#  'exhausted',
#  'working',
#  'another',
#  'carnival',
#  'tomorrow',
#  'blah',
#  'samithegreat',
#  'wet',
#  'attic',
#  'jasperrrr',
#  'got',
#  'bigg',
#  'fight',
#  'prom',
#  'date',
#  'guess',
#  'mee',
#  'beautifulloser',
#  'see',
#  'use',
#  'one',
#  'funny',
#  'normal',
#  'seriously',
#  'using',
#  'ginger',
#  'haha',
#  'looked',
#  'swhelband',
#  'ok',
#  'thanks',
#  'head',
#  'looking',
#  'forward',
#  'erwinspinueva',
#  'much',
#  'til',
#  'bone',
#  'cheese',
#  'egg',
#  'n',
#  'welchs',
#  'grape',
#  'loll',
#  'omg',
#  'anyone',
#  'finale',
#  'hill',
#  'last',
#  'missed',
#  'watching',
#  'entourage',
#  'tommcfly',
#  'doesnt',
#  'sense',
#  'josamuffin',
#  'migotogirl',
#  'get',
#  'iphone',
#  'great',
#  'band',
#  'broke',
#  'week',
#  'depressing',
#  'mileycyrus',
#  'yay',
#  'congrats',
#  'voted',
#  'enjoying',
#  'heat',
#  'yesterday',
#  'getting',
#  'bit',
#  'pajjie',
#  'yea',
#  'good',
#  'monday',
#  'quite',
#  'fast',
#  'jmatthewflyzik',
#  'morning',
#  'feel',
#  'without',
#  'want',
#  'baaaaaad',
#  'trackle',
#  'squarespace',
#  'dannymcfly',
#  'danny',
#  'propa',
#  'teeth',
#  'white',
#  'manchseter',
#  'gig',
#  'alreet',
#  'hows',
#  'ur',
#  'show',
#  'x',
#  'ly',
#  'rolled',
#  'hunter',
#  'blush',
#  'play',
#  'wife',
#  'new',
#  'paladin',
#  'recruit',
#  'friend',
#  'pretty',
#  'hope',
#  'terrorize',
#  'bgs',
#  'mdobson',
#  'original',
#  'title',
#  'better',
#  'author',
#  'control',
#  'including',
#  'cover',
#  'sorry',
#  'people',
#  'twitter',
#  'pc',
#  'becose',
#  'holland',
#  'dont',
#  'let',
#  'send',
#  'msn',
#  'mobile',
#  'said',
#  'amp',
#  'say',
#  'gray',
#  'hair',
#  'wish',
#  'silver',
#  'streak',
#  'stacy',
#  'london',
#  'word',
#  'pant',
#  'eddieizzard',
#  'seems',
#  'caused',
#  'confusion',
#  'explain',
#  'everyone',
#  'loveodt',
#  'kim',
#  'r',
#  'freakin',
#  'robsmada',
#  'valilor',
#  'yeah',
#  'twitterfon',
#  'child',
#  'driving',
#  'freaking',
#  'crazy',
#  'ugh',
#  'jazz',
#  'appreciation',
#  'test',
#  'tonight',
#  'hummingbird',
#  'fave',
#  'faves',
#  'dunno',
#  'beautiful',
#  'take',
#  'walk',
#  'finally',
#  'used',
#  'early',
#  'gme',
#  'oh',
#  'wishing',
#  'home',
#  'sober',
#  'loser',
#  'co',
#  'worker',
#  'jake',
#  'drunk',
#  'fuck',
#  'open',
#  'gon',
#  'na',
#  'dr',
#  'fitness',
#  'fatguy',
#  'radio',
#  'october',
#  'dang',
#  'book',
#  'peep',
#  'gpok',
#  'download',
#  'user',
#  'kirasworld',
#  'bf',
#  'know',
#  'nothing',
#  'art',
#  'draw',
#  'anyway',
#  'goodnight',
#  'thomasfiss',
#  'hey',
#  'thomas',
#  'really',
#  'actually',
#  'shed',
#  'tear',
#  'eliiiiza',
#  'turn',
#  'nice',
#  'rice',
#  'reefergladness',
#  'technically',
#  'nomnomnom',
#  'keij',
#  'duboce',
#  'triangle',
#  'back',
#  'duckydoestv',
#  'joy',
#  'moving',
#  'ikea',
#  'bookcase',
#  'together',
#  'urhot',
#  'trying',
#  'believe',
#  'powerful',
#  'negativity',
#  'stronger',
#  'totally',
#  'peachypictures',
#  'annoying',
#  'result',
#  'jer',
#  'alright',
#  'lake',
#  'murray',
#  'duck',
#  'minnie',
#  'best',
#  'ever',
#  'evening',
#  'relaxing',
#  'cheking',
#  'youtube',
#  'fafinettex',
#  'hardy',
#  'desinfecting',
#  'hand',
#  'mlre',
#  'finishing',
#  'chilly',
#  'nightshift',
#  'nite',
#  'whatever',
#  'zzzzzzz',
#  'physical',
#  'coo',
#  'lettin',
#  'steam',
#  'newly',
#  'seeded',
#  'lawn',
#  'loving',
#  'steve',
#  'coogan',
#  'raise',
#  'dylan',
#  'moran',
#  'sniff',
#  'never',
#  'chance',
#  'goodbye',
#  'adrian',
#  'long',
#  'rip',
#  'kraziyanto',
#  'advice',
#  'true',
#  'timhaines',
#  'saw',
#  'dave',
#  'message',
#  'hear',
#  'jenniferkee',
#  'worse',
#  'yet',
#  'receive',
#  'news',
#  'rather',
#  'dark',
#  'rhcp',
#  'universe',
#  'big',
#  'green',
#  'fan',
#  'prefer',
#  'though',
#  'litmus',
#  'scattering',
#  'picture',
#  'design',
#  'website',
#  'www',
#  'studiokaydesigns',
#  'com',
#  'encore',
#  'htm',
#  'hottea',
#  'fellow',
#  'otaku',
#  'sweet',
#  'dream',
#  'school',
#  'sport',
#  'agin',
#  'computer',
#  'angry',
#  'selenagomez',
#  'um',
#  'id',
#  'cool',
#  'hah',
#  'promise',
#  'fort',
#  'wayne',
#  'study',
#  'already',
#  'else',
#  'gruesome',
#  'internet',
#  'connection',
#  'problem',
#  'burned',
#  'three',
#  'hour',
#  'fix',
#  'booo',
#  'tryna',
#  'switch',
#  'movie',
#  'momz',
#  'hang',
#  'blessed',
#  'mom',
#  'brother',
#  'moment',
#  'bed',
#  'try',
#  'figuring',
#  'business',
#  'later',
#  'christinalemmey',
#  'dh',
#  'hospital',
#  'due',
#  'abdomenal',
#  'pain',
#  'clean',
#  'house',
#  'beloved',
#  'done',
#  'excuse',
#  'followfriday',
#  'coz',
#  'busy',
#  'ahead',
#  'gethighonair',
#  'sometime',
#  'miss',
#  'aidan',
#  'damnn',
#  'many',
#  'tutions',
#  'fucking',
#  'frustrating',
#  'la',
#  'campus',
#  'energy',
#  'place',
#  'celsbels',
#  'aha',
#  'ride',
#  'office',
#  'bike',
#  'loathe',
#  'royal',
#  'mail',
#  'inflicting',
#  'alwaysatlukoil',
#  'phone',
#  'mean',
#  'text',
#  'ipod',
#  'touch',
#  'wifi',
#  'mrsddoubleu',
#  'least',
#  'call',
#  'bully',
#  'dmwilsonh',
#  'blazer',
#  'putting',
#  'dibs',
#  'yr',
#  'dollar',
#  'portebello',
#  'mushroom',
#  'burger',
#  'arnt',
#  'carl',
#  'jr',
#  'around',
#  'atlanta',
#  'judez',
#  'xo',
#  'pfft',
#  'venue',
#  'close',
#  'awekay',
#  'kelsey',
#  'happened',
#  'tried',
#  'upload',
#  'stuck',
#  'boy',
#  'fill',
#  'dear',
#  'louise',
#  'rennison',
#  'pls',
#  'writing',
#  'georgia',
#  'begs',
#  'bereft',
#  'knowing',
#  'billinman',
#  'four',
#  'letter',
#  'domain',
#  'shore',
#  'free',
#  'feeling',
#  'sick',
#  'hate',
#  'weather',
#  'helping',
#  'fact',
#  'hella',
#  'birthday',
#  'godmother',
#  'tv',
#  'e',
#  'bueno',
#  'papagai',
#  'promotion',
#  'addys',
#  'jealous',
#  'maybe',
#  'verizon',
#  'drink',
#  'cry',
#  'favorite',
#  'greener',
#  'pasture',
#  'sure',
#  'sheila',
#  'money',
#  'stuff',
#  'whats',
#  'deal',
#  'pwease',
#  'fucked',
#  'angel',
#  'demon',
#  'thrilling',
#  'liked',
#  'da',
#  'vinci',
#  'code',
#  'definitely',
#  'read',
#  'mcgrewsecurity',
#  'heard',
#  'sound',
#  'right',
#  'hollywilli',
#  'jcab',
#  'yer',
#  'preachin',
#  'choir',
#  'baby',
#  'ti',
#  'shit',
#  'sometimes',
#  'sangfroid',
#  'idea',
#  'ngfr',
#  'yup',
#  'catch',
#  'late',
#  'tweet',
#  'wendytanwhite',
#  'colour',
#  'soho',
#  'weekend',
#  'emmadawson',
#  'dog',
#  'boho',
#  'canterbury',
#  'nicolesayss',
#  'legittt',
#  'armed',
#  'high',
#  'drummer',
#  'woooh',
#  'quot',
#  'click',
#  'joeymcintyre',
#  'ready',
#  'atl',
#  'thursday',
#  'wait',
#  'ahhh',
#  'manage',
#  'pack',
#  'nike',
#  'box',
#  'start',
#  'packing',
#  'pasar',
#  'malam',
#  'room',
#  'semangats',
#  'sitting',
#  'finished',
#  'wut',
#  'bored',
#  'v',
#  'wild',
#  'ferrell',
#  'discovery',
#  'channel',
#  'judging',
#  'promos',
#  'episode',
#  'epic',
#  'rosiefresh',
#  'heylushh',
#  'tooooo',
#  'havnt',
#  'seen',
#  'age',
#  'skool',
#  'left',
#  'tho',
#  'foot',
#  'hurt',
#  'pm',
#  'lunch',
#  'acne',
#  'followin',
#  'power',
#  'turning',
#  'bad',
#  'killing',
#  'son',
#  'bday',
#  'may',
#  'ruined',
#  'watchin',
#  'smh',
#  'plane',
#  'crash',
#  'victim',
#  'ebonyrose',
#  'wrong',
#  'sun',
#  'cloudy',
#  'boohoo',
#  'kaliedeskope',
#  'watch',
#  'stay',
#  'online',
#  'benjamin',
#  'crinkle',
#  'luna',
#  'sparkle',
#  'scarlett',
#  'johannson',
#  'cat',
#  'benamuen',
#  'ppl',
#  'write',
#  'coolkid',
#  'kinda',
#  'god',
#  'please',
#  'sooner',
#  'weelissa',
#  'lady',
#  'edinburgh',
#  'cancel',
#  'b',
#  'booking',
#  'gone',
#  'hotel',
#  'checkmate',
#  'kitabet',
#  'istiklal',
#  'busker',
#  'carry',
#  'wherever',
#  'sherinep',
#  'hopefully',
#  'spending',
#  'planning',
#  'post',
#  'yes',
#  'alexc',
#  'international',
#  'sushi',
#  'celebrating',
#  'hapas',
#  'donnaspeaks',
#  'coming',
#  'probably',
#  'grit',
#  'toast',
#  'biscuit',
#  'sausage',
#  'juice',
#  'milk',
#  'yoga',
#  'beach',
#  'called',
#  'trance',
#  'progressive',
#  'reason',
#  'revel',
#  'asot',
#  'social',
#  'medium',
#  'unlocking',
#  'awesome',
#  'potential',
#  'behavioral',
#  'disorder',
#  'ot',
#  'gym',
#  'sandrabrownma',
#  'web',
#  'interview',
#  'relationship',
#  'pattern',
#  'messed',
#  'break',
#  'jennifer',
#  'anniston',
#  'set',
#  'math',
#  'kaps',
#  'chem',
#  'queensland',
#  'win',
#  'fo',
#  'sho',
#  'netherlands',
#  'aaaaaa',
#  'clothes',
#  'boring',
#  'little',
#  'banana',
#  'pancake',
#  'glad',
#  'jc',
#  'mo',
#  'storm',
#  'st',
#  'louis',
#  'iamdolleyes',
#  'poppy',
#  'mal',
#  'malzadoll',
#  'lame',
#  'ask',
#  'help',
#  'angus',
#  'accepted',
#  'midnight',
#  'idk',
#  'fall',
#  'asleep',
#  'beyonc',
#  'live',
#  'globen',
#  'arena',
#  'stockholm',
#  'woman',
#  'shake',
#  'search',
#  'app',
#  'following',
#  'flex',
#  'tutorial',
#  'kind',
#  'dimdim',
#  'wake',
#  'nn',
#  'anymore',
#  'lakesgirl',
#  'lost',
#  'justinphillip',
#  'forgive',
#  'shystieuk',
#  'pahhhhh',
#  'matching',
#  'underwear',
#  'lmao',
#  'shysite',
#  'ty',
#  'cheerin',
#  'chattin',
#  'ddlovato',
#  'emilyosment',
#  'choice',
#  'award',
#  'till',
#  'concert',
#  'alive',
#  'headache',
#  'blast',
#  'music',
#  'daniielee',
#  'heart',
#  'broken',
#  'rihannadaily',
#  'serious',
#  'hungry',
#  'fair',
#  'asmith',
#  'def',
#  'rostered',
#  'workin',
#  'sat',
#  'lately',
#  'restaurant',
#  'alydenisof',
#  'amazing',
#  'inspiration',
#  'father',
#  'brazil',
#  'shame',
#  'yo',
#  'ck',
#  'ny',
#  'boo',
#  'pen',
#  'snuck',
#  'washer',
#  'several',
#  'shirt',
#  'load',
#  'burnallzombies',
#  'hera',
#  'killer',
#  'game',
#  'killed',
#  'carlos',
#  'adama',
#  'xbox',
#  'burnt',
#  'hot',
#  'aloe',
#  'vera',
#  'adrence',
#  'smiling',
#  'hon',
#  'xoxo',
#  'nettuts',
#  'ellen',
#  'star',
#  'akaalexandria',
#  'answer',
#  'question',
#  'helped',
#  'sickness',
#  'football',
#  'death',
#  'pete',
#  'yorn',
#  'covering',
#  'order',
#  'slipped',
#  'fell',
#  'hard',
#  'tile',
#  'butt',
#  'ouchhhh',
#  'wowitsheather',
#  'nd',
#  'fav',
#  'charlie',
#  'yah',
#  'heather',
#  'found',
#  'anywhere',
#  'interweb',
#  'tomfelton',
#  'tom',
#  'everything',
#  'facebook',
#  'published',
#  'ooffoo',
#  'page',
#  'join',
#  'eco',
#  'atop',
#  'nature',
#  'making',
#  'netflix',
#  'jackie',
#  'robinson',
#  'story',
#  'superman',
#  'cora',
#  'lee',
#  'asked',
#  'bring',
#  ...]

# %% [markdown]
# ### Building Features
#
# Now let's build the features. Using the top 5,000 words, create a 2-dimensional matrix to record whether each of those words is contained in each document (tweet). Then you also have an output column to indicate whether the sentiment in each tweet is positive. For example, assuming your bag of words has 5 items (`['one', 'two', 'three', 'four', 'five']`) out of 4 documents (`['A', 'B', 'C', 'D']`), your feature set is essentially:
#
# | Doc | one | two | three | four | five | is_positive |
# |---|---|---|---|---|---|---|
# | A | True | False | False | True | False | True |
# | B | False | False | False | True | True | False |
# | C | False | True | False | False | False | True |
# | D | True | False | False | False | True | False|
#
# However, because the `nltk.NaiveBayesClassifier.train` class we will use in the next step does not work with Pandas dataframe, the structure of your feature set should be converted to the Python list looking like below:
#
# ```python
# [
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': False
# 	}, True),
# 	({
# 		'one': False,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': True
# 	}, False),
# 	({
# 		'one': False,
# 		'two': True,
# 		'three': False,
# 		'four': False,
# 		'five': False
# 	}, True),
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': False,
# 		'five': True
# 	}, False)
# ]
# ```
#
# To help you in this step, watch the [following video](https://www.youtube.com/watch?v=-vVskDsHcVc) to learn how to build the feature set with Python and NLTK. The source code in this video can be found [here](https://pythonprogramming.net/words-as-features-nltk-tutorial/).

# %% [markdown]
# [![Building Features](building-features.jpg)](https://www.youtube.com/watch?v=-vVskDsHcVc)

# %%
def find_features(x):
    words = set(x)
    features = {}
    for i in wlist:
        features[i] = (i in words)
    return features

# %%
featuresets = [(find_features(tweet), target) for (tweet, target) in list(zip(df['text_processed'], df['target']))]

print(len(featuresets))
# Out:
# 1000

# %% [markdown]
# ### Building and Traininng Naive Bayes Model
#
# In this step you will split your feature set into a training and a test set. Then you will create a Bayes classifier instance using `nltk.NaiveBayesClassifier.train` ([example](https://www.nltk.org/book/ch06.html)) to train with the training dataset.
#
# After training the model, call `classifier.show_most_informative_features()` to inspect the most important features. The output will look like:
#
# ```
# Most Informative Features
# 	    snow = True            False : True   =     34.3 : 1.0
# 	  easter = True            False : True   =     26.2 : 1.0
# 	 headach = True            False : True   =     20.9 : 1.0
# 	    argh = True            False : True   =     17.6 : 1.0
# 	unfortun = True            False : True   =     16.9 : 1.0
# 	    jona = True             True : False  =     16.2 : 1.0
# 	     ach = True            False : True   =     14.9 : 1.0
# 	     sad = True            False : True   =     13.0 : 1.0
# 	  parent = True            False : True   =     12.9 : 1.0
# 	  spring = True            False : True   =     12.7 : 1.0
# ```
#
# The [following video](https://www.youtube.com/watch?v=rISOsUaTrO4) will help you complete this step. The source code in this video can be found [here](https://pythonprogramming.net/naive-bayes-classifier-nltk-tutorial/).

# %% [markdown]
# [![Building and Training NB](nb-model-building.jpg)](https://www.youtube.com/watch?v=rISOsUaTrO4)

# %%
train_set, test_set = featuresets[:500], featuresets[500:]

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
classifier.show_most_informative_features(10)
# Out:
# 0.626
# Most Informative Features
#                     miss = True                0 : 4      =      9.9 : 1.0
#                   thanks = True                4 : 0      =      6.9 : 1.0
#                    sorry = True                0 : 4      =      6.1 : 1.0
#                      say = True                4 : 0      =      5.2 : 1.0
#                    movie = True                4 : 0      =      4.5 : 1.0
#                   pretty = True                4 : 0      =      4.5 : 1.0
#                     fall = True                4 : 0      =      3.8 : 1.0
#                    funny = True                4 : 0      =      3.8 : 1.0
#                     baby = True                0 : 4      =      3.5 : 1.0
#                      omg = True                0 : 4      =      3.5 : 1.0

# %% [markdown]
# ### Testing Naive Bayes Model
#
# Now we'll test our classifier with the test dataset. This is done by calling `nltk.classify.accuracy(classifier, test)`.
#
# As mentioned in one of the tutorial videos, a Naive Bayes model is considered OK if your accuracy score is over 0.6. If your accuracy score is over 0.7, you've done a great job!

# %%
# is ok , probably shoudl have used more data than 1000

# %% [markdown]
# ## Bonus Question 1: Improve Model Performance
#
# If you are still not exhausted so far and want to dig deeper, try to improve your classifier performance. There are many aspects you can dig into, for example:
#
# * Improve stemming and lemmatization. Inspect your bag of words and the most important features. Are there any words you should furuther remove from analysis? You can append these words to further remove to the stop words list.
#
# * Remember we only used the top 5,000 features to build model? Try using different numbers of top features. The bottom line is to use as few features as you can without compromising your model performance. The fewer features you select into your model, the faster your model is trained. Then you can use a larger sample size to improve your model accuracy score.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 2: Machine Learning Pipeline
#
# In a new Jupyter Notebook, combine all your codes into a function (or a class). Your new function will execute the complete machine learning pipeline job by receiving the dataset location and output the classifier. This will allow you to use your function to predict the sentiment of any tweet in real time.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 3: Apache Spark
#
# If you have completed the Apache Spark advanced topic lab, what you can do is to migrate your pipeline from local to a Databricks Notebook. Share your notebook with your instructor and classmates to show off your achievements!

# %%
# your code here
